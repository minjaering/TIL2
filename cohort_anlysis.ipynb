# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic')
mpl.font_manager._rebuild()

# 해당 코드 실행이 완료되면, 반드시 상단의 런타임 > 런타임 다시 시작 누르기. 그리고 재실행
# Out:
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155632 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import pandas as pd # python에서의 엑셀과 같은 역할
import numpy as np # 계산을 편하게 해 주는 라이브러리
import matplotlib.pyplot as plt # 시각화 ㅊㅊㅊ
import seaborn as sns # 시각화

import matplotlib.ticker as ticker # 시각화
import matplotlib.dates as mdates # 시각화

import warnings
warnings.filterwarnings('ignore')

# %%
### google drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-5-7fa2b21890d0> in <module>()
#       1 ### google drive mount
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     107       force_remount=force_remount,
#     108       timeout_ms=timeout_ms,
# --> 109       ephemeral=True)
#     110
#     111
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     122   if ephemeral:
#     123     _message.blocking_request(
# --> 124         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     125
#     126   mountpoint = _os.path.expanduser(mountpoint)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     173   request_id = send_request(
#     174       request_type, request, parent=parent, expect_reply=True)
# --> 175   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# # _01. 데이터 로드

# %%
df = pd.read_csv('/content/drive/MyDrive/00_learning_spoons/example_files/week_04/df_seat.csv')
df_seat = df.copy()
df_seat.head()
# Out:
#    user_key  sales_key branch sales_type items  term paid_by   paid_date  \
# 0         1    1067235    01호         매출   자유석     1      카드  2021-04-11
# 1         2    1055317    01호         매출   싱글석     3      카드  2021-03-28
# 2         2    1136132    01호         매출   싱글석     2      카드  2021-06-27
# 3         2    1210305    01호         매출   싱글석     1      카드  2021-08-31
# 4         2    1239778    01호         매출   싱글석     1      카드  2021-09-30
#
#    start_date    end_date  ... paid_month  start_month  end_month  start_day  \
# 0  2021-04-11  2021-05-10  ...          4            4          5     Sunday
# 1  2021-04-03  2021-07-02  ...          3            4          7   Saturday
# 2  2021-07-03  2021-08-31  ...          6            7          8   Saturday
# 3  2021-09-01  2021-09-30  ...          8            9          9  Wednesday
# 4  2021-10-01  2021-10-30  ...          9           10         10     Friday
#
#    next_start_date  user_lead_1  user_check  elapsed_days  item_seg  \
# 0       2021-04-03            2          -1           NaN        자유
# 1       2021-07-03            2           0           0.0        고정
# 2       2021-09-01            2           0           0.0        고정
# 3       2021-10-01            2           0           0.0        고정
# 4       2021-06-19            3          -1           NaN        고정
#
#   item_seg_np
# 0          자유
# 1          고정
# 2          고정
# 3          고정
# 4          고정
#
# [5 rows x 26 columns]

# %% [markdown]
#     * 실습 목적
#         * 1년( 12개월 )의 월 결제 데이터를 통해
#         * Retention을 알아보고,
#         * 시기별로 어떠한 특성이 있는 지 찾아보기

# %% [markdown]
# ## 1.1. 데이터 spec 파악

# %%
df_seat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71293 entries, 0 to 71292
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_key            71293 non-null  int64
#  1   sales_key           71293 non-null  int64
#  2   branch              71293 non-null  object
#  3   sales_type          71293 non-null  object
#  4   items               71293 non-null  object
#  5   term                71293 non-null  int64
#  6   paid_by             71293 non-null  object
#  7   paid_date           71293 non-null  object
#  8   start_date          71293 non-null  object
#  9   end_date            71293 non-null  object
#  10  payment_type        71293 non-null  object
#  11  discount            71293 non-null  int64
#  12  paid_amount         71293 non-null  int64
#  13  avg_paid_amount_1   71293 non-null  float64
#  14  avg_paid_amount     61454 non-null  float64
#  15  avg_paid_amount_np  61454 non-null  float64
#  16  paid_month          71293 non-null  int64
#  17  start_month         71293 non-null  int64
#  18  end_month           71293 non-null  int64
#  19  start_day           71293 non-null  object
#  20  next_start_date     71292 non-null  object
#  21  user_lead_1         71293 non-null  int64
#  22  user_check          71293 non-null  int64
#  23  elapsed_days        52345 non-null  float64
#  24  item_seg            71293 non-null  object
#  25  item_seg_np         71293 non-null  object
# dtypes: float64(4), int64(10), object(12)
# memory usage: 14.1+ MB

# %% [markdown]
# ## 1.2. Cohort에 필요한 컬럼만 가져오기

# %%
df_base = df_seat[['user_key', 'branch', 'sales_type', 'items', 'paid_date', 'item_seg']]
df_base.head()
# Out:
#    user_key branch sales_type items   paid_date item_seg
# 0         1    01호         매출   자유석  2021-04-11       자유
# 1         2    01호         매출   싱글석  2021-03-28       고정
# 2         2    01호         매출   싱글석  2021-06-27       고정
# 3         2    01호         매출   싱글석  2021-08-31       고정
# 4         2    01호         매출   싱글석  2021-09-30       고정

# %% [markdown]
# # _02. data cleansing

# %% [markdown]
# ## 2.1. 매출만 남기기

# %%
df_base['sales_type'].unique().tolist()
# Out:
# ['매출', '매출취소']

# %%
df_base = df_base[df_base['sales_type'] == '매출']
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63104 entries, 0 to 71292
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_key    63104 non-null  int64
#  1   branch      63104 non-null  object
#  2   sales_type  63104 non-null  object
#  3   items       63104 non-null  object
#  4   paid_date   63104 non-null  object
#  5   item_seg    63104 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 3.4+ MB

# %% [markdown]
# ## 2.2. data type 맞추기

# %% [markdown]
#     * 날짜 데이터가 문자열로 되어있다
#     * 문자열 → 날짜 형식으로 data type을 변경 해 줌

# %%
# df_base['paid_date'] = df_base['paid_date'].astype('datetime64[ns]')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63104 entries, 0 to 71292
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_key    63104 non-null  int64
#  1   branch      63104 non-null  object
#  2   sales_type  63104 non-null  object
#  3   items       63104 non-null  object
#  4   paid_date   63104 non-null  datetime64[ns]
#  5   item_seg    63104 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 3.4+ MB

# %%
# Out:
#    user_key branch sales_type items  paid_date item_seg
# 0         1    01호         매출   자유석 2021-04-11       자유
# 1         2    01호         매출   싱글석 2021-03-28       고정

# %% [markdown]
# # _03. 분석하기 좋은 data로 만들기

# %% [markdown]
# ## 3.1. 최초 구매일 컬럼 생성

# %%
# Out:
#    user_key branch sales_type items  paid_date item_seg first_paid
# 0         1    01호         매출   자유석 2021-04-11       자유 2021-04-11
# 1         2    01호         매출   싱글석 2021-03-28       고정 2021-03-28
# 2         2    01호         매출   싱글석 2021-06-27       고정 2021-03-28
# 3         2    01호         매출   싱글석 2021-08-31       고정 2021-03-28
# 4         2    01호         매출   싱글석 2021-09-30       고정 2021-03-28

# %% [markdown]
# ## 3.2. 월 단위 형태로 data 맞추기

# %%
# .dt.strftime
# Out:
#    user_key branch sales_type items  paid_date item_seg first_paid first_ym  \
# 0         1    01호         매출   자유석 2021-04-11       자유 2021-04-11  2021-04
# 1         2    01호         매출   싱글석 2021-03-28       고정 2021-03-28  2021-03
# 2         2    01호         매출   싱글석 2021-06-27       고정 2021-03-28  2021-03
# 3         2    01호         매출   싱글석 2021-08-31       고정 2021-03-28  2021-03
# 4         2    01호         매출   싱글석 2021-09-30       고정 2021-03-28  2021-03
#
#    paid_ym
# 0  2021-04
# 1  2021-03
# 2  2021-06
# 3  2021-08
# 4  2021-09

# %% [markdown]
# ### 3.2.1 data range 확인

# %%
# Out:
# 13

# %%
# Out:
# 2021-01
# 2022-01

# %%
# Out:
# 2021-01
# 2021-12

# %%
# Out:
#    user_key branch sales_type items  paid_date item_seg first_paid first_ym  \
# 0         1    01호         매출   자유석 2021-04-11       자유 2021-04-11  2021-04
# 1         2    01호         매출   싱글석 2021-03-28       고정 2021-03-28  2021-03
# 2         2    01호         매출   싱글석 2021-06-27       고정 2021-03-28  2021-03
# 3         2    01호         매출   싱글석 2021-08-31       고정 2021-03-28  2021-03
# 4         2    01호         매출   싱글석 2021-09-30       고정 2021-03-28  2021-03
#
#    paid_ym
# 0  2021-04
# 1  2021-03
# 2  2021-06
# 3  2021-08
# 4  2021-09

# %% [markdown]
# ## 3.3. 매 월 단위 동질 집단 리텐션 숫자 생성

# %%
# Out:
#    first_ym  paid_ym  user_cnts
# 0   2021-01  2021-01       3781
# 1   2021-01  2021-02       1805
# 2   2021-01  2021-03       1381
# 3   2021-01  2021-04        963
# 4   2021-01  2021-05        899
# ..      ...      ...        ...
# 73  2021-10  2021-11        318
# 74  2021-10  2021-12        120
# 75  2021-11  2021-11        840
# 76  2021-11  2021-12        263
# 77  2021-12  2021-12       1105
#
# [78 rows x 3 columns]

# %% [markdown]
# ### 3.3.1. 매 월 데이터가 있는 지 확인 해 보기

# %% [markdown]
# ![Screen Shot 2022-05-26 at 14.48.58.png](data:image/png;base64,...)

# %% [markdown]
# * 현재 데이터는 1년 12달에 대한 cohort를 보기 위한 것 이므로,
#     * 12 + 11 + 10 + ... + 3 + 2 + 1 = 총 row 개수 78과 맞는 지 확인 해 보면 된다
#     * ( 12 + 1 ) + ( 11 + 2 ) + ... + ( 7 + 6 ) = 13 x 6 = 78

# %%
# 현재 데이터는 1년 12달에 대한 cohort를 보기 위한 것 이므로,
# 12 + 11 + 10 + ... + 3 + 2 + 1
# ( 12 + 1 ) + ( 11 + 2 ) + ... + ( 7 + 6 ) = 13 x 6 = 78

# %%
# 실제로 월마다 모든 cohort 개수가 있는 지 확인
# Out:
# 2021-01    12
# 2021-02    11
# 2021-03    10
# 2021-04     9
# 2021-05     8
# 2021-06     7
# 2021-07     6
# 2021-08     5
# 2021-09     4
# 2021-10     3
# 2021-11     2
# 2021-12     1
# Name: first_ym, dtype: int64

# %% [markdown]
# ### 3.3.2. Cohort 기간 컬럼 생성

# %%
# Out:
#   first_ym  paid_ym  user_cnts  cohort_period
# 0  2021-01  2021-01       3781              0
# 1  2021-01  2021-02       1805              1
# 2  2021-01  2021-03       1381              2
# 3  2021-01  2021-04        963              3
# 4  2021-01  2021-05        899              4

# %%
# user_cnts: numeric data type 여부 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_ym       78 non-null     object
#  1   paid_ym        78 non-null     object
#  2   user_cnts      78 non-null     int64
#  3   cohort_period  78 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 2.6+ KB

# %% [markdown]
# ### 3.3.3. 기준이 될 것을 index로, 값으로 표현될 것을 컬럼으로 만들기

# %%
# Out:
#                         paid_ym  user_cnts
# first_ym cohort_period
# 2021-01  0              2021-01       3781
#          1              2021-02       1805
#          2              2021-03       1381
#          3              2021-04        963
#          4              2021-05        899
# ...                         ...        ...
# 2021-10  1              2021-11        318
#          2              2021-12        120
# 2021-11  0              2021-11        840
#          1              2021-12        263
# 2021-12  0              2021-12       1105
#
# [78 rows x 2 columns]

# %% [markdown]
# ### 3.3.4. 값을 기준으로 unstack

# %%
# Out:
# cohort_period      0       1       2      3      4      5      6      7   \
# first_ym
# 2021-01        3781.0  1805.0  1381.0  963.0  899.0  879.0  949.0  784.0
# 2021-02        1896.0   888.0   546.0  483.0  448.0  447.0  361.0  326.0
# 2021-03        1948.0   807.0   650.0  602.0  470.0  387.0  395.0  348.0
# 2021-04        1309.0   540.0   421.0  283.0  233.0  236.0  223.0  171.0
# 2021-05        1245.0   578.0   384.0  277.0  223.0  208.0  145.0   84.0
# 2021-06        1641.0   733.0   473.0  403.0  346.0  208.0  118.0    NaN
# 2021-07        2323.0   842.0   589.0  512.0  331.0  175.0    NaN    NaN
# 2021-08         933.0   429.0   306.0  188.0   93.0    NaN    NaN    NaN
# 2021-09        1088.0   504.0   266.0  131.0    NaN    NaN    NaN    NaN
# 2021-10         833.0   318.0   120.0    NaN    NaN    NaN    NaN    NaN
# 2021-11         840.0   263.0     NaN    NaN    NaN    NaN    NaN    NaN
# 2021-12        1105.0     NaN     NaN    NaN    NaN    NaN    NaN    NaN
#
# cohort_period     8      9      10     11
# first_ym
# 2021-01        756.0  747.0  537.0  307.0
# 2021-02        307.0  249.0  143.0    NaN
# 2021-03        284.0  151.0    NaN    NaN
# 2021-04         80.0    NaN    NaN    NaN
# 2021-05          NaN    NaN    NaN    NaN
# 2021-06          NaN    NaN    NaN    NaN
# 2021-07          NaN    NaN    NaN    NaN
# 2021-08          NaN    NaN    NaN    NaN
# 2021-09          NaN    NaN    NaN    NaN
# 2021-10          NaN    NaN    NaN    NaN
# 2021-11          NaN    NaN    NaN    NaN
# 2021-12          NaN    NaN    NaN    NaN

# %% [markdown]
# ### 3.3.5. unstack 결과를, 첫 코호트 기간의 값으로 나눠주기 → retention 산출

# %%
# Out:
# first_ym
# 2021-01    3781.0
# 2021-02    1896.0
# 2021-03    1948.0
# 2021-04    1309.0
# 2021-05    1245.0
# 2021-06    1641.0
# 2021-07    2323.0
# 2021-08     933.0
# 2021-09    1088.0
# 2021-10     833.0
# 2021-11     840.0
# 2021-12    1105.0
# Name: 0, dtype: float64

# %%
# Out:
# cohort_period   0         1         2         3         4         5   \
# first_ym
# 2021-01        1.0  0.477387  0.365247  0.254695  0.237768  0.232478
# 2021-02        1.0  0.468354  0.287975  0.254747  0.236287  0.235759
# 2021-03        1.0  0.414271  0.333676  0.309035  0.241273  0.198665
# 2021-04        1.0  0.412529  0.321620  0.216196  0.177998  0.180290
# 2021-05        1.0  0.464257  0.308434  0.222490  0.179116  0.167068
# 2021-06        1.0  0.446679  0.288239  0.245582  0.210847  0.126752
# 2021-07        1.0  0.362462  0.253551  0.220405  0.142488  0.075334
# 2021-08        1.0  0.459807  0.327974  0.201501  0.099678       NaN
# 2021-09        1.0  0.463235  0.244485  0.120404       NaN       NaN
# 2021-10        1.0  0.381753  0.144058       NaN       NaN       NaN
# 2021-11        1.0  0.313095       NaN       NaN       NaN       NaN
# 2021-12        1.0       NaN       NaN       NaN       NaN       NaN
#
# cohort_period        6         7         8         9         10        11
# first_ym
# 2021-01        0.250992  0.207353  0.199947  0.197567  0.142026  0.081195
# 2021-02        0.190401  0.171941  0.161920  0.131329  0.075422       NaN
# 2021-03        0.202772  0.178645  0.145791  0.077515       NaN       NaN
# 2021-04        0.170359  0.130634  0.061115       NaN       NaN       NaN
# 2021-05        0.116466  0.067470       NaN       NaN       NaN       NaN
# 2021-06        0.071907       NaN       NaN       NaN       NaN       NaN
# 2021-07             NaN       NaN       NaN       NaN       NaN       NaN
# 2021-08             NaN       NaN       NaN       NaN       NaN       NaN
# 2021-09             NaN       NaN       NaN       NaN       NaN       NaN
# 2021-10             NaN       NaN       NaN       NaN       NaN       NaN
# 2021-11             NaN       NaN       NaN       NaN       NaN       NaN
# 2021-12             NaN       NaN       NaN       NaN       NaN       NaN

# %% [markdown]
# # _04. 시각화

# %% [markdown]
# *   위의 3.3번의 해당하는 과정을 한 번에

# %%
# temp_df = df_base[df_base['branch'] == temp_branch]

# %% [markdown]
# # ★ 번외: Cohort x Segmentation

# %% [markdown]
# ## 7호 & 8호 & 9호점에 대해 별도 cohort

# %%
# Out:
#    user_key branch sales_type items  paid_date item_seg first_paid first_ym  \
# 0         1    01호         매출   자유석 2021-04-11       자유 2021-04-11  2021-04
# 1         2    01호         매출   싱글석 2021-03-28       고정 2021-03-28  2021-03
#
#    paid_ym
# 0  2021-04
# 1  2021-03

# %%
selected_branches = ['07호', '08호', '09호']

# %% [markdown]
# ## 빠진 이 채우기: 08호점

# %%
# Out:
#        user_key branch sales_type items  paid_date item_seg first_paid  \
# 11261      2867    08호         매출  포커스석 2021-01-25       자유 2021-01-25
# 11262      2867    08호         매출  포커스석 2021-03-04       자유 2021-01-25
# 11263      2868    08호         매출   메가석 2021-03-01       자유 2021-03-01
# 11264      2868    08호         매출   메가석 2021-03-30       자유 2021-03-01
# 11266      2869    08호         매출  포커스석 2021-10-25       자유 2021-10-25
# ...         ...    ...        ...   ...        ...      ...        ...
# 12606      3255    08호         매출  포커스석 2021-02-08       자유 2021-02-08
# 12607      3256    08호         매출   자유석 2021-06-27       자유 2021-06-27
# 12608      3256    08호         매출  포커스석 2021-06-28       자유 2021-06-27
# 12610      3256    08호         매출  포커스석 2021-07-25       자유 2021-06-27
# 12611      3256    08호         매출  포커스석 2021-12-22       자유 2021-06-27
#
#       first_ym  paid_ym
# 11261  2021-01  2021-01
# 11262  2021-01  2021-03
# 11263  2021-03  2021-03
# 11264  2021-03  2021-03
# 11266  2021-10  2021-10
# ...        ...      ...
# 12606  2021-02  2021-02
# 12607  2021-06  2021-06
# 12608  2021-06  2021-06
# 12610  2021-06  2021-07
# 12611  2021-06  2021-12
#
# [1231 rows x 9 columns]

# %%
# Out:
#    first_ym  paid_ym  user_cnts
# 0   2021-01  2021-01         62
# 1   2021-01  2021-02         28
# 2   2021-01  2021-03         23
# 3   2021-01  2021-04         17
# 4   2021-01  2021-05         17
# ..      ...      ...        ...
# 70  2021-10  2021-11          8
# 71  2021-10  2021-12          3
# 72  2021-11  2021-11         15
# 73  2021-11  2021-12          2
# 74  2021-12  2021-12         21
#
# [75 rows x 3 columns]

# %%
# Out:
# 2021-01    12
# 2021-02    11
# 2021-03    10
# 2021-04     8
# 2021-05     7
# 2021-06     7
# 2021-07     6
# 2021-08     5
# 2021-09     3
# 2021-10     3
# 2021-11     2
# 2021-12     1
# Name: first_ym, dtype: int64

# %%
# first_ym 2021-04: 9개 있어야 하지만 8개 있음
# first_ym 2021-05: 8개 있어야 하지만 7개 있음
# first_ym 2021-09: 4개 있어야 하지만 3개 있음

# %%
# Out:
#    first_ym  paid_ym  user_cnts
# 33  2021-04  2021-04         21
# 34  2021-04  2021-05         13
# 35  2021-04  2021-06          9
# 36  2021-04  2021-07          2
# 37  2021-04  2021-08          3
# 38  2021-04  2021-09          3
# 39  2021-04  2021-10          2
# 40  2021-04  2021-11          1

# %%
# ↑ 저곳의 data frame에, paid_ym 2021-12가 빠져있음

# %%
# Out:
#    first_ym  paid_ym  user_cnts
# 41  2021-05  2021-05         28
# 42  2021-05  2021-06         11
# 43  2021-05  2021-07          8
# 44  2021-05  2021-08          5
# 45  2021-05  2021-09          3
# 46  2021-05  2021-10          5
# 47  2021-05  2021-11          1

# %%
# ↑ 저곳의 data frame에, paid_ym 2021-12가 빠져있음

# %%
# Out:
#    first_ym  paid_ym  user_cnts
# 66  2021-09  2021-09         24
# 67  2021-09  2021-10          9
# 68  2021-09  2021-11          7

# %%
# ↑ 저곳의 data frame에, paid_ym 2021-12가 빠져있음

# %%
# 채우기 전 data frame
# Out:
#    first_ym  paid_ym  user_cnts
# 0   2021-01  2021-01         62
# 1   2021-01  2021-02         28
# 2   2021-01  2021-03         23
# 3   2021-01  2021-04         17
# 4   2021-01  2021-05         17
# ..      ...      ...        ...
# 70  2021-10  2021-11          8
# 71  2021-10  2021-12          3
# 72  2021-11  2021-11         15
# 73  2021-11  2021-12          2
# 74  2021-12  2021-12         21
#
# [75 rows x 3 columns]

# %%
# first_ym 2021-04 // 2021-05 // 2021-09에 각각 paid_ym 2021-12가 빠져있음

# %%
df_8_user
# Out:
#     first_ym  paid_ym  user_cnts
#  0   2021-01  2021-01         62
#  1   2021-01  2021-02         28
#  2   2021-01  2021-03         23
#  3   2021-01  2021-04         17
#  4   2021-01  2021-05         17
# ..       ...      ...        ...
#  73  2021-11  2021-12          2
#  74  2021-12  2021-12         21
# -1   2021-04  2021-12          0
# -2   2021-05  2021-12          0
# -3   2021-09  2021-12          0
#
# [78 rows x 3 columns]

# %%
# Out:
#    first_ym  paid_ym  user_cnts
# 0   2021-01  2021-01         62
# 1   2021-01  2021-02         28
# 2   2021-01  2021-03         23
# 3   2021-01  2021-04         17
# 4   2021-01  2021-05         17
# ..      ...      ...        ...
# 73  2021-10  2021-11          8
# 74  2021-10  2021-12          3
# 75  2021-11  2021-11         15
# 76  2021-11  2021-12          2
# 77  2021-12  2021-12         21
#
# [78 rows x 3 columns]

# %%
# 완성

# %%
# 빠진 이 끼워맞춘 것 확인

# %%
df_base.head()
# Out:
#    user_key branch sales_type items  paid_date item_seg first_paid first_ym  \
# 0         1    01호         매출   자유석 2021-04-11       자유 2021-04-11  2021-04
# 1         2    01호         매출   싱글석 2021-03-28       고정 2021-03-28  2021-03
# 2         2    01호         매출   싱글석 2021-06-27       고정 2021-03-28  2021-03
# 3         2    01호         매출   싱글석 2021-08-31       고정 2021-03-28  2021-03
# 4         2    01호         매출   싱글석 2021-09-30       고정 2021-03-28  2021-03
#
#    paid_ym
# 0  2021-04
# 1  2021-03
# 2  2021-06
# 3  2021-08
# 4  2021-09

# %% [markdown]
# ## 결제항목( item_seg ) 조합 추가

# %%
df_base['item_seg'].unique().tolist()
# Out:
# ['자유', '고정', '단기']
